# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# ## To Predict PetalLengthCm using Linear Regression

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# df = pd.get_dummies(df,columns=['Species'])

# %% [markdown]
# #### SPLITTING

# %%
df['Species'].replace({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2},inplace=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
sns.pairplot(df)

# %% [markdown]
# ### CREATING INDEPENDENT AND DEPENDENT VARIABLES

# %%
x = df.drop(['PetalLengthCm','Id'],axis=1)
y = df['PetalLengthCm']

# %% [markdown]
# ### SPLITING TRAINING AND TESTING DATASETS

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# ### CREATING INSTANCE

# %%
lr = LinearRegression()

# %% [markdown]
# ### BUILDING THE MODEL

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
# TESTING EVALUATION
# mse
mse = mean_squared_error(y_test,y_pred)
print('mse is :',mse)
# rmse
rmse = np.sqrt(mse)
print('rmse is :',rmse)
# r2
r2 = r2_score(y_test,y_pred)
print('r2_score is ',r2)
# Out:
# mse is : 0.16593983779811677
# rmse is : 0.40735713790004563
# r2_score is  0.9440746488351008

# %%
# TRAINING EVALUATION

y_pred_train = lr.predict(x_train)

mse = mean_squared_error(y_train,y_pred_train)
print('mse is :',mse)
# rmse
rmse = np.sqrt(mse)
print('rmse is :',rmse)
# r2
r2 = r2_score(y_train,y_pred_train)
print('r2_score is ',r2)
# Out:
# mse is : 0.07050311401669075
# rmse is : 0.2655242249149609
# r2_score is  0.9773311552262677

# %% [markdown]
# ### DUPM TO PICKLE FILE

# %%
import pickle
with open('LinearModelIris.pkl','wb')as f:
    pickle.dump(lr,f)

# %%
x.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalWidthCm', 'Species'], dtype='object')

# %%
Project_data = {'columns':list(x.columns)}

# %%
Project_data = {'Species':{0:'Iris-setosa', 1:'Iris-versicolor', 2:'Iris-virginica'},'columns':list(x.columns)}

# %%
import json
with open('Project_data.json','w')as f:
    json.dump(Project_data,f)

# %%
x.head(1).T
# Out:
#                  0
# SepalLengthCm  5.1
# SepalWidthCm   3.5
# PetalWidthCm   0.2
# Species        0.0

# %%
# #   a=int(self.model.predict([test_array]))
# Project_data['Species'][1]
